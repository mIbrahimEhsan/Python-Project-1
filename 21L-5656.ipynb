# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
def check_input(array):  # Function To check input values of the 2-D array
    r_c = 0
    c_c = 0
    x = len(array[0])
    for c in range(0,3):  #for checking column wise
        for r in range(1,3):
            if(array[0][c]==array[r][c] or type(array[r][c])==str):
                c_c = c_c + 1
    for i in range(0,x):  #for checking row wise
        for j in range(1,x):
            if(array[r][0]==array[r][c] or type(array[r][c])==str):
                r_c = r_c + 1   
    if(r_c!=0 or c_c!=0): #bool value
        return False
    else:
        return True

# %%
test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

def check_input(array):  
    r_c = 0
    c_c = 0
    x = len(array[0])
    for c in range(0,3):  
        for r in range(1,3):
            if(array[0][c]==array[r][c] or type(array[r][c])==str):
                c_c = c_c + 1
                
    for r in range(0,x):  
        for c in range(1,x):
            if(array[r][0]==array[r][c] or type(array[r][c])==str):
                r_c = r_c + 1   
    if(r_c!=0 or c_c!=0): 
        return False
    else:
        return True

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %%
import pandas as pd
load=pd.read_csv("StudentMarkSheet.csv")
print(load)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
import pandas as pd
import numpy as np
import csv

reader=csv.reader(open("StudentMarkSheet.csv"))
t_lines=len(list(reader))-1 #No. of lines with Null values
load=pd.read_csv("StudentMarkSheet.csv")
r = load.dropna()  #no. of lines Without Null
NULL=len(r)
x=t_lines-NULL #N0. of null lines
print(r)
print("Total number of lines: ",t_lines)
print("Total number of NULL lines: ",NULL)
print("Total number of lines without null:",x)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [196 rows x 4 columns]
# Total number of lines:  200
# Total number of NULL lines:  196
# Total number of lines without null: 4

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
print(load[load['Student name']=='James Walker']) #specific student
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
av_bio=load[load["Exam name"]=="Biology"] #calculating average for all subjects
av_bio=av_bio["Marks"]
total=av_bio.sum()
length=len(av_bio)
a=total/length
print("Biology Average: ",a) 

av_phy=load[load["Exam name"]=="Physics"]
av_phy=av_phy["Marks"]
total=av_phy.sum()
length=len(av_phy)
b=total/length
print("Physics Average: ",b)

av_phil=load[load["Exam name"]=="Philosophy"]
av_phil=av_phil["Marks"]
total=av_phil.sum()
length=len(av_phil)
c=total/length
print("Philosophy Average: ",c)


av_chem=load[load["Exam name"]=="Chemistry"]
av_chem=av_chem["Marks"]
total=av_chem.sum()
length=len(av_chem)
d=total/length
print("Chemistry Average: ",d)


av_soc=load[load["Exam name"]=="Sociology"]
av_soc=av_soc["Marks"]
total=av_soc.sum()
length=len(av_soc)
e=total/length
print("Sociology Average: ",e)


av_math=load[load["Exam name"]=="Mathematics"]
av_math=av_math["Marks"]
total=av_math.sum()
length=len(av_math)
f=total/length
print("Mathematics Average: ",f)
# Out:
# Biology Average:  47.89473684210526
# Physics Average:  51.76190476190476
# Philosophy Average:  46.026315789473685
# Chemistry Average:  48.7037037037037
# Sociology Average:  56.026315789473685
# Mathematics Average:  47.648648648648646

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
import matplotlib.pyplot as plt
subject=["Biology","Physics","Philosophy","Chemistry","Sociology","Maths"]
average=[a,b,c,d,e,f]
plt.bar(subject,average,fc="orange") #Graph bar color set to orange
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
info=pd.read_csv("CatData.csv")
print(info.dropna()) #NULL values excluded
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable: Mass (kg)
# independant variable: Tail Length (cm)

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

a= int(len (info)*0.8)
train=info[:a] #0 to range
test=info[a:] #range till end

reg=linear_model.LinearRegression()
value_2=np.array(train[["Mass (kg)"]]) #Dependent Variable
value_1=np.array(train[["Tail Length (cm)"]]) #Independent Variable

reg.fit(value_1,value_2)
slope=reg.coef_
intercept=reg.intercept_

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
coef_value = reg.coef_
intr_value = reg.intercept_
print("Slope: ", coef_value)
print("Intercept: ",intr_value)
# Out:
# Slope:  [[0.48913766]]
# Intercept:  [-5.57328662]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.xlabel("Tail Length (cm)")
plt.ylabel("Mass (kg)")
plt.title("Tail Length vs Mass")
plt.scatter(train["Tail Length (cm)"],train["Mass (kg)"]) #display's scatter values
plt.plot(value_1,value_1*coef_value[0]+intr_value, color = 'black')
plt.show()
